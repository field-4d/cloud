# %%
import os
from google.cloud import bigquery
from google.oauth2 import service_account
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px

# %%
def query_combined_data(client, dataset_id, table_id, print_cost=False):
    """
    Execute a combined query to get distinct sensors, total entries, and last timestamp grouped by ExperimentData_Exp_name.

    Parameters:
        client (bigquery.Client): Initialized BigQuery client.
        dataset_id (str): The ID of the dataset.
        table_id (str): The ID of the table.
        print_cost (bool): Flag to print query cost.

    Returns:
        tuple: (query results, estimated cost in USD)
    """
    # Define the combined SQL query
    query = f"""
    SELECT
      ExperimentData_Exp_name,
      COUNT(DISTINCT SensorData_Name) AS sensor_count,
      COUNT(*) AS num_entries,
      MAX(TimeStamp) AS last_timestamp
    FROM
      `iucc-f4d.{dataset_id}.{table_id}`
    GROUP BY
      ExperimentData_Exp_name
    ORDER BY
      ExperimentData_Exp_name;
    """

    # Configure the query for a dry run to estimate costs
    job_config = bigquery.QueryJobConfig(dry_run=True, use_query_cache=False)
    query_job = client.query(query, job_config=job_config)

    # Calculate estimated cost
    bytes_processed = query_job.total_bytes_processed
    estimated_cost = (bytes_processed / (1024 ** 4)) * 5  # Cost in USD ($5 per TB)

    if print_cost:
        print(f"Estimated cost for table {table_id} in dataset {dataset_id}: ${estimated_cost:.4f}")

    # Execute the actual query
    query_job = client.query(query)
    return query_job.result(), estimated_cost

# %%
def query_daily_data(client, dataset_id, table_id):
    """
    Query to calculate the amount of data found per day for each dataset_id.

    Parameters:
        client (bigquery.Client): Initialized BigQuery client.
        dataset_id (str): The ID of the dataset.
        table_id (str): The ID of the table.

    Returns:
        pd.DataFrame: DataFrame containing daily data counts.
    """
    query = f"""
    SELECT
      DATE(TimeStamp) AS date,
      COUNT(*) AS num_entries
    FROM
      `iucc-f4d.{dataset_id}.{table_id}`
    GROUP BY
      date
    ORDER BY
      date;
    """

    query_job = client.query(query)
    results = query_job.result()

      # Calculate estimated cost
    bytes_processed = query_job.total_bytes_processed
    estimated_cost = (bytes_processed / (1024 ** 4)) * 5  # Cost in USD ($5 per TB)


    # Convert query results to a DataFrame
    data = []
    for row in results:
        data.append({
            "dataset_id": dataset_id,
            "date": row.date,
            "num_entries": row.num_entries
        })

    return pd.DataFrame(data),estimated_cost

# %%
def create_daily_plot(df):
    """
    Create a plot of the amount of data per day for each dataset_id.

    Parameters:
        df (pd.DataFrame): The DataFrame containing daily data counts.
    """
    plt.figure(figsize=(12, 8))

    for dataset_id, group in df.groupby('dataset_id'):
        plt.plot(group['date'], group['num_entries'], marker='o', label=dataset_id)

    plt.xlabel('Date')
    plt.ylabel('Number of Entries')
    plt.title('Daily Data Counts per Dataset')
    plt.legend(title='Dataset ID', bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
def query_experiment_data(client, dataset_id, table_id):
    """
    Query to get experiment data with the number of entries, first timestamp, and last timestamp.

    Parameters:
        client (bigquery.Client): Initialized BigQuery client.
        dataset_id (str): The ID of the dataset.
        table_id (str): The ID of the table.

    Returns:
        pd.DataFrame: DataFrame containing the query results.
    """
    query = f"""
    SELECT
        Table_DATA.ExperimentData_Exp_name,
        COUNT(*) AS num_entries,
        ARRAY_AGG(DISTINCT SensorData_Name) AS sensor_names,
        MIN(Table_DATA.TimeStamp) AS first_timestamp,
        MAX(Table_DATA.TimeStamp) AS last_timestamp
    FROM
        `iucc-f4d.{dataset_id}.{table_id}` AS Table_DATA
    GROUP BY
        Table_DATA.ExperimentData_Exp_name
    ORDER BY
        SAFE_CAST(REGEXP_EXTRACT(Table_DATA.ExperimentData_Exp_name, r'exp_(\\d+)') AS INT64);
    """

    query_job = client.query(query)
    results = query_job.result()

    # Convert query results to a DataFrame
    data = []
    for row in results:
        data.append({
            "dataset_id": dataset_id,
            "table_id": table_id,
            "ExperimentData_Exp_name": row.ExperimentData_Exp_name,
            "num_entries": row.num_entries,
            "sensor_names": row.sensor_names,
            "first_timestamp": row.first_timestamp,
            "last_timestamp": row.last_timestamp
        })

    return pd.DataFrame(data)

# %%
def query_compare_experiments(client, dataset_id, table_id, experiment_names, sensor_name):
    """
    Compare sensor readings across multiple experiments.
    """
    experiments_list = ", ".join([f"'{exp}'" for exp in experiment_names])
    
    query = f"""
    SELECT
        ExperimentData_Exp_name,
        COUNT(*) as reading_count,
        AVG(SAFE_CAST(SensorData_Value AS FLOAT64)) as avg_value,
        STDDEV(SAFE_CAST(SensorData_Value AS FLOAT64)) as std_dev
    FROM
        `iucc-f4d.{dataset_id}.{table_id}`
    WHERE
        ExperimentData_Exp_name IN ({experiments_list})
        AND SensorData_Name = '{sensor_name}'
    GROUP BY
        ExperimentData_Exp_name
    ORDER BY
        ExperimentData_Exp_name
    """
    
    return client.query(query).to_dataframe()

# %% [markdown]
# # Here you read and connect to the GCP server

# %%
# Path to your credentials JSON file
credentials_path = "read_BQ.json"

# Load credentials from the JSON file
credentials = service_account.Credentials.from_service_account_file(credentials_path)

# Initialize BigQuery client
client = bigquery.Client(credentials=credentials, project="iucc-f4d")

# Initialize an empty list to store data for the DataFrame
data = []

dataset_costs = {}  # Dictionary to store costs per dataset
combined_cost = 0   # Variable to track the combined cost

# %%
big_df = pd.DataFrame()
for dataset in client.list_datasets():
    dataset_id = dataset.dataset_id
    for table in client.list_tables(dataset_id):
        if dataset_id == "user_device_permission":
            continue
        table_id = table.table_id
        print(f"The table {table_id} in dataset {dataset_id}")
        df = query_experiment_data(client, dataset_id, table_id)
        big_df = pd.concat([big_df, df], ignore_index=True)
        # Query combined data and get estimated cost
big_df = big_df.sort_values(by="last_timestamp", ascending=False)
display(big_df)
# Out:
# The table 2ccf6730ab5f in dataset Icore_Pi
# The table d83adde260d1 in dataset Yakir
# The table 2ccf6730ab8c in dataset developerroom
# The table d83adde26159 in dataset developerroom
# The table 2ccf6774b0ae in dataset idanhouse
# The table 2ccf6730ab7a in dataset menachem_moshelion
# The table d83adde2608f in dataset menachem_moshelion
# The table d83adde261b0 in dataset menachem_moshelion
# The table d83adde260d1 in dataset yakir
# The table d83adde260d1_Older_BackUp in dataset yakir
#             dataset_id      table_id       ExperimentData_Exp_name  \
# 52               yakir  d83adde260d1  exp_2_Yatir_all_new_img_15_4
# 51               yakir  d83adde260d1   exp_1_Yatir_all_new_img_8_4
# 1             Icore_Pi  2ccf6730ab5f            exp_5_Assaf_tomato
# 11       developerroom  2ccf6730ab8c             exp_1_Cellular Pi
# 27       developerroom  d83adde26159            exp_17_All_Togther
# ..                 ...           ...                           ...
# 32  menachem_moshelion  d83adde2608f             exp_1_Lab_Freezer
# 35  menachem_moshelion  d83adde2608f                   exp_4_Check
# 36  menachem_moshelion  d83adde2608f                 exp_5_Check_2
# 33  menachem_moshelion  d83adde2608f        exp_2_Light_Experiment
# 34  menachem_moshelion  d83adde2608f                  exp_3_jumper
#
#     num_entries                                       sensor_names  \
# 52        65828  [Rad_N_1_in, Temp_N_3_in, Temp_S_1_out, Rad_S_...
# 51       183942  [Temp_N_1_in, Temp_S_2_out, Rad_S_3_in, Rad_S_...
# 1        428483  [17d up, 5c down, 13c up, 2a down, 5c up, 13c ...
# 11        37266                                         [cellu_pi]
# 27         7418         [V2_A, V2_B, V2_C, V1_A, V1_B, V1_C, V1_D]
# ..          ...                                                ...
# 32        84351                                          [Freezer]
# 35       736241  [18, 37, 54, 49, 42, 66, 14, 56, 13, 39, 40, 7...
# 36        22470                               [Sensor_2, Sensor_1]
# 33       911790  [B_8, B_7, B_10, T_5, B_6, T_3, T_2, T_1, T_4,...
# 34       116690                                           [jumper]
#
#              first_timestamp            last_timestamp
# 52 2025-04-15 16:11:00+00:00 2025-05-18 15:26:00+00:00
# 51 2025-04-08 18:05:00+00:00 2025-05-18 15:26:00+00:00
# 1  2025-01-05 11:38:00+00:00 2025-05-18 15:23:00+00:00
# 11 2025-03-27 14:18:00+00:00 2025-05-18 15:21:00+00:00
# 27 2025-05-14 14:06:00+00:00 2025-05-18 15:20:00+00:00
# ..                       ...                       ...
# 32 2024-10-14 14:53:00+00:00 2024-11-24 12:24:00+00:00
# 35 2024-11-17 14:19:00+00:00 2024-11-24 12:24:00+00:00
# 36 2024-11-17 17:22:00+00:00 2024-11-24 12:24:00+00:00
# 33 2024-10-14 15:28:00+00:00 2024-11-24 12:15:00+00:00
# 34 2024-10-14 15:25:00+00:00 2024-11-18 09:46:00+00:00
#
# [63 rows x 7 columns]

# %%
import ipywidgets as widgets
from IPython.display import display

# Create a dropdown widget for ExperimentData_Exp_name
experiment_dropdown = widgets.Dropdown(
    options=big_df['ExperimentData_Exp_name'].unique(),
    description='Experiment:',
    style={'description_width': 'initial'}
)

# Display the dropdown
display(experiment_dropdown)
# Out:
# Dropdown(description='Experiment:', options=('exp_2_Yatir_all_new_img_15_4', 'exp_1_Yatir_all_new_img_8_4', 'e…

# %%
# Iterate through datasets and tables, then run the query for each
for dataset in client.list_datasets():
    dataset_id = dataset.dataset_id
    dataset_total_cost = 0

    for table in client.list_tables(dataset_id):
        table_id = table.table_id
        print(f"Running query for dataset: {dataset_id}, table: {table_id}")
        # if table_id user_device_permission skip
        if dataset_id == "user_device_permission":
            continue
        
        results, estimated_cost = query_combined_data(client, dataset_id, table_id, print_cost=True)

        # Add query results to the data list
        for row in results:
            data.append({
                "dataset_id": dataset_id,
                "table_id": table_id,
                "ExperimentData_Exp_name": row.ExperimentData_Exp_name,
                "sensor_count": row.sensor_count,
                "num_entries": row.num_entries,
                "last_timestamp": row.last_timestamp,
                "estimated_cost": estimated_cost
            })

        dataset_total_cost += estimated_cost

    # Store total cost for the dataset
    dataset_costs[dataset_id] = dataset_total_cost
    combined_cost += dataset_total_cost

    print(f"Total estimated cost for dataset {dataset_id}: ${dataset_total_cost:.4f}")

# Print combined cost for all datasets
print(f"Combined estimated cost for all datasets: ${combined_cost:.10f}")

# Create a DataFrame from the collected data
df = pd.DataFrame(data)
# Out:
# Running query for dataset: Icore_Pi, table: 2ccf6730ab5f
# Estimated cost for table 2ccf6730ab5f in dataset Icore_Pi: $0.0002
# Total estimated cost for dataset Icore_Pi: $0.0002
# Running query for dataset: Yakir, table: d83adde260d1
# Estimated cost for table d83adde260d1 in dataset Yakir: $0.0001
# Total estimated cost for dataset Yakir: $0.0001
# Running query for dataset: developerroom, table: 2ccf6730ab8c
# Estimated cost for table 2ccf6730ab8c in dataset developerroom: $0.0000
# Running query for dataset: developerroom, table: d83adde26159
# Estimated cost for table d83adde26159 in dataset developerroom: $0.0000
# Total estimated cost for dataset developerroom: $0.0000
# Running query for dataset: idanhouse, table: 2ccf6774b0ae
# Estimated cost for table 2ccf6774b0ae in dataset idanhouse: $0.0000
# Total estimated cost for dataset idanhouse: $0.0000
# Running query for dataset: menachem_moshelion, table: 2ccf6730ab7a
# Estimated cost for table 2ccf6730ab7a in dataset menachem_moshelion: $0.0005
# Running query for dataset: menachem_moshelion, table: d83adde2608f
# Estimated cost for table d83adde2608f in dataset menachem_moshelion: $0.0025
# Running query for dataset: menachem_moshelion, table: d83adde261b0
# Estimated cost for table d83adde261b0 in dataset menachem_moshelion: $0.0001
# Total estimated cost for dataset menachem_moshelion: $0.0030
# Running query for dataset: user_device_permission, table: mac_to_device
# Running query for dataset: user_device_permission, table: mac_to_device_temp
# Running query for dataset: user_device_permission, table: permissions
# Running query for dataset: user_device_permission, table: user_table
# Total estimated cost for dataset user_device_permission: $0.0000
# Running query for dataset: yakir, table: d83adde260d1
# Estimated cost for table d83adde260d1 in dataset yakir: $0.0001
# Running query for dataset: yakir, table: d83adde260d1_Older_BackUp
# Estimated cost for table d83adde260d1_Older_BackUp in dataset yakir: $0.0001
# Total estimated cost for dataset yakir: $0.0001
# Combined estimated cost for all datasets: $0.0034716406

# %%
# Initialize an empty list to store data for the DataFrame
daily_data = []
conmbined_cost = 0
# Iterate through datasets and tables, then run the daily data query for each
for dataset in client.list_datasets():
    dataset_id = dataset.dataset_id

    for table in client.list_tables(dataset_id):
        if dataset_id == "user_device_permission":
            continue
        table_id = table.table_id
        daily_df, estimated_cost = query_daily_data(client, dataset_id, table_id)
        print(f"Running daily data query for dataset: {dataset_id}, table: {table_id}, estimated cost: ${estimated_cost:.4f}")
        combined_cost += estimated_cost
        daily_data.append(daily_df)

# Combine all daily data into a single DataFrame
daily_data_df = pd.concat(daily_data, ignore_index=True)
print(f"Combined estimated cost for all datasets: ${combined_cost:.10f}")
# Display the DataFrame
print(daily_data_df)
# Out:
# Running daily data query for dataset: Icore_Pi, table: 2ccf6730ab5f, estimated cost: $0.0000
# Running daily data query for dataset: Yakir, table: d83adde260d1, estimated cost: $0.0000
# Running daily data query for dataset: developerroom, table: 2ccf6730ab8c, estimated cost: $0.0000
# Running daily data query for dataset: developerroom, table: d83adde26159, estimated cost: $0.0000
# Running daily data query for dataset: idanhouse, table: 2ccf6774b0ae, estimated cost: $0.0000
# Running daily data query for dataset: menachem_moshelion, table: 2ccf6730ab7a, estimated cost: $0.0001
# Running daily data query for dataset: menachem_moshelion, table: d83adde2608f, estimated cost: $0.0006
# Running daily data query for dataset: menachem_moshelion, table: d83adde261b0, estimated cost: $0.0000
# Running daily data query for dataset: yakir, table: d83adde260d1, estimated cost: $0.0000
# Running daily data query for dataset: yakir, table: d83adde260d1_Older_BackUp, estimated cost: $0.0000
# Combined estimated cost for all datasets: $0.0042330744
#     dataset_id        date  num_entries
# 0     Icore_Pi  2024-12-09         1759
# 1     Icore_Pi  2024-12-10         4128
# 2     Icore_Pi  2024-12-11         1155
# 3     Icore_Pi  2024-12-12         3839
# 4     Icore_Pi  2024-12-13         1119
# ..         ...         ...          ...
# 674      yakir  2025-03-26         3176
# 675      yakir  2025-03-29           27
# 676      yakir  2025-04-01           60
# 677      yakir  2025-04-02         8595
# 678      yakir  2025-04-03         6741
#
# [679 rows x 3 columns]

# %%
# convert date to datetime
daily_data_df['date'] = pd.to_datetime(daily_data_df['date'])
# sort the data by date
daily_data_df = daily_data_df.sort_values(by=["dataset_id",'date'])
# calculate the comlutative sum of num_entries foer each dataset_id
daily_data_df["cumulative_num_entries"] = daily_data_df.groupby('dataset_id')['num_entries'].cumsum()

db_sum = 0
dicty_db_size = {}
for day in sorted(daily_data_df.date.unique()):
    # Filter the data for the current day
    day_data = daily_data_df[daily_data_df['date'] == day]
    # Create a plot of the data for the current day
    db_sum+=day_data["cumulative_num_entries"].sum()
    dicty_db_size[day] = db_sum
# create df of dicty_db_size
df_db_size = pd.DataFrame(list(dicty_db_size.items()),columns = ['date','db_size'])

# %%
from plotly.subplots import make_subplots

import plotly.graph_objects as go

# Create subplots
fig = make_subplots(rows=2, cols=1, shared_xaxes=True, 
                    subplot_titles=('Cumulative Number of Entries Over Time', 'Database Size Over Time'))

# Add the first plot (Cumulative Number of Entries Over Time)
for dataset_id in daily_data_df['dataset_id'].unique():
    dataset_df = daily_data_df[daily_data_df['dataset_id'] == dataset_id]
    fig.add_trace(go.Scatter(x=dataset_df['date'], y=dataset_df['cumulative_num_entries'], mode='lines+markers', name=dataset_id), row=1, col=1)

# Add the second plot (Database Size Over Time)
fig.add_trace(go.Scatter(x=df_db_size['date'], y=df_db_size['db_size'], mode='lines+markers', name='Database Size'), row=2, col=1)

# Update layout
fig.update_layout(height=800, width=1000, title_text="Data Analysis", template='plotly_white')
fig.update_xaxes(title_text="Date", row=2, col=1)
fig.update_yaxes(title_text="Cumulative Number of Entries", row=1, col=1)
fig.update_yaxes(title_text="Database Size", row=2, col=1)

# Show the plot
fig.show()
